# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( "metrics_crudas.csv" )

df.head()
# Out:
#      match  team1  direct_play  counterattack  T_maintenance  T_build_up  \
# 0  2499719   1609   356.903763      38.475388     253.640098  448.696552
# 1  2499719   1631   151.371756      14.920580     116.388608  432.763020
# 2  2499720   1625   395.131011      37.841597     190.948160  650.679142
# 3  2499720   1651   126.913376      25.463668     105.211156  109.993449
# 4  2499721   1610   361.440581      35.106563     499.289176  314.879369
#
#    T_zona_media  flow_rate  crossing  pressure_point  pressure_loss  shots  \
# 0    716.029417  20.868180         8          2086.0      50.528341      9
# 1    211.277036   7.828017         3          1135.0      31.902325      0
# 2   1158.997713  18.684612        11          3026.0     198.091060      4
# 3    143.042525   4.997537         2           825.0      30.294175      1
# 4    642.552792  11.853229         8          1412.0      99.727621      3
#
#       liga
# 0  England
# 1  England
# 2  England
# 3  England
# 4  England

# %%
liga='Germany'
met ='direct_play'

arx = f'{liga}/red_{met}.dat'
red = pd.read_csv(arx)

arx = f'../all_2/{liga}/red_{met}.dat'
red2 = pd.read_csv(arx)


plt.scatter( red["fij"], red2["fij"] )

# %%
plt.scatter(   )
